# %%
import sqlite3
import pandas as pd

# %%
db = sqlite3.connect("scram.db")

# %%
products = pd.read_sql('''SELECT DISTINCT  Name 
FROM  Product''', db)

products.to_json(orient="records")
# Out:
# ['{',
#  '"',
#  'N',
#  'a',
#  'm',
#  'e',
#  '"',
#  ':',
#  '{',
#  '"',
#  '0',
#  '"',
#  ':',
#  '"',
#  '\\',
#  '"',
#  'B',
#  'e',
#  'g',
#  'i',
#  'n',
#  'n',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'A',
#  'n',
#  'a',
#  'l',
#  'o',
#  'g',
#  'i',
#  'e',
#  's',
#  '\\',
#  '"',
#  ' ',
#  'C',
#  'a',
#  'r',
#  'd',
#  ' ',
#  'G',
#  'a',
#  'm',
#  'e',
#  '"',
#  ',',
#  '"',
#  '1',
#  '"',
#  ':',
#  '"',
#  '\\',
#  '"',
#  'W',
#  'h',
#  'a',
#  't',
#  ' ',
#  'G',
#  'o',
#  'e',
#  's',
#  ' ',
#  'T',
#  'o',
#  'g',
#  'e',
#  't',
#  'h',
#  'e',
#  'r',
#  '?',
#  '\\',
#  '"',
#  ' ',
#  'C',
#  'a',
#  'r',
#  'd',
#  ' ',
#  'G',
#  'a',
#  'm',
#  'e',
#  '"',
#  ',',
#  '"',
#  '2',
#  '"',
#  ':',
#  '"',
#  '\\',
#  '"',
#  'W',
#  'h',
#  'a',
#  't',
#  "'",
#  's',
#  ' ',
#  'S',
#  'i',
#  'l',
#  'l',
#  'y',
#  '?',
#  '\\',
#  '"',
#  ' ',
#  'C',
#  'a',
#  'r',
#  'd',
#  ' ',
#  'G',
#  'a',
#  'm',
#  'e',
#  '"',
#  ',',
#  '"',
# ...
